# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
mean1 = (0.1 + np.random.rand(100))/4

# %%
mean2 = mean.copy()

# %%
for i in range(20):
    mean2[i] += 0.3

# %%
std = 0.001; cov = np.eye(100) * std

# %%
x = np.random.multivariate_normal(mean1, cov, 1000)
y = np.random.multivariate_normal(mean2, cov, 1000)

# %%
plt.plot(range(100), x[2, :])
plt.plot(range(100), y[2, :])

# %%
np.save('data_test_100_ad.npy', y)

# %%
np.save('data_test_100_cn.npy', x)
